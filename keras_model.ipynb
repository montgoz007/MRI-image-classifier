# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
img0 = r'C:\Users\steph\OneDrive\Documents\Data\MRnet\MRNet-v1.0\train\axial\0000.npy'

# %%
image_size = (256, 256)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    r'C:\Users\steph\OneDrive\Documents\Data\MRnet\MRNet-v1.0\train\axial',
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    r'C:\Users\steph\OneDrive\Documents\Data\MRnet\MRNet-v1.0\valid\axial',
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 0 files belonging to 0 classes.
# Using 0 files for training.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\montVenv\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     469               as_ref=input_arg.is_ref,
# --> 470               preferred_dtype=default_dtype)
#     471         except TypeError as err:
#
# ~\anaconda3\envs\montVenv\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1474           "Tensor conversion requested dtype %s for Tensor with dtype %s: %r" %
# -> 1475           (dtype.name, value.dtype.name, value))
#    1476     return value
#
# ...
